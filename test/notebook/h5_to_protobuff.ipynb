# %%
import tensorflow as tf 
from tensorflow.python.saved_model import builder as pb_builder

# %%
# set learning phase to 0 since the model is already trained
tf.keras.backend.set_learning_phase(0)

#load the model
model = tf.keras.models.load_model("/content/drive/My Drive/IOT/SIMULATION - ROB D'ASSIST/Scripts/saved model/Line_Following_CNN_v1.h5")

#convert h5 to protobuffer
builder = pb_builder.SavedModelBuilder("/content/drive/My Drive/IOT/SIMULATION - ROB D'ASSIST/Scripts/saved protobuff/line following")
builder.save()
# Out:
# INFO:tensorflow:SavedModel written to: /content/drive/My Drive/IOT/SIMULATION - ROB D'ASSIST/Scripts/saved protobuff/line following/saved_model.pb
# b"/content/drive/My Drive/IOT/SIMULATION - ROB D'ASSIST/Scripts/saved protobuff/line following/saved_model.pb"
